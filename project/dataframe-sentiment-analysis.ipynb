# %% [markdown]
# ### **PLN (processamento de lingaugem natural) aplicado**
# ### **PIPELINE**
# ![alt text](img/_pipeline.png)
#
# **Sentença** - frase em si
# **Tokenização** - separação das palavras do texto, buscando o contexto da frase
# **(Pos) Tagging** - verifica qual o tipo da palavra verbo, pronome etc.
# **Lemmantizantion** - fatia as palavras por exemplo, 'andando' - and - andei - andarei
# **Stopwords** - palavras que podem ser removidas, sem influência no modelo
# **Dependency parsing** - identifica as relações de dependência entre as palavra
# **Nouns Phrases** - (Frases Nominais) são grupos de palavras que funcionam juntas como um único substantivo na frase
# **Name Identify** recognition (NER) -  (Reconhecimento de Entidades Nomeadas) é uma técnica usada para identificar e classificar entidades nomeadas em um texto, como nomes de pessoas, locais, organizações, datas, números, entre outros.

# %% [markdown]
# #### **Bibliotecas utilizadas** ambas para Processamento de Linguagem Natural ( PLN ) exceto pandas, algumas apenas citadas
#   **NLTK**
#   **Spacy**
#   **Open NLP**
#   **Stanza**
#   **Pandas**
#   **Azure AI Text Analysis**
#   **Azure AI Translator**
#   **IBM Watson**

# %%
import pandas as pd # data
import string # processing
import re # processing
import nltk # processing
from nltk.corpus import stopwords # processing
from nltk.tokenize import RegexpTokenizer # processing
import unidecode # processing
import requests, uuid, json # data translator - Azure AI

# Sentiment Analysis
from azure.core.credentials import AzureKeyCredential
from azure.ai.textanalytics import TextAnalyticsClient

# Emotion Analysis
from ibm_watson import NaturalLanguageUnderstandingV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
from ibm_watson.natural_language_understanding_v1 import Features, EmotionOptions
# Se necessário 👇🏽
# pip uninstall urllib3
# pip install urllib3==1.26.8

import os
from dotenv import load_dotenv

load_dotenv()

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rapha\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ### Env's

# %%
azure_ai_translator_key = os.getenv("AZURE_AI_TRANSLATOR_KEY")
azure_ai_sentiment_key = os.getenv("AZURE_AI_SENTIMENT_KEY")
ibm_watson_emotion_key = os.getenv("IBM_WATSON_EMOTION_KEY")

# %% [markdown]
# #### Funções de tratamento de texto

# %%
def TextToLower(text):
    return text.lower()


def RemoveBlank(text):
    return text.strip()


def RemovePunctuation(text):
    punct = string.punctuation
    punct = punct.replace("'","")
    return text.translate(str.maketrans("","",punct))


def RemoveEmoji(text):
    emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F" # emoticons
        u"\U0001F300-\U0001F5FF" # simbolos
        u"\U0001F680-\U0001F6FF" # transporte
        u"\U0001F1E0-\U0001F1FF"
        u"\U00002702-\U000027B0" 
        u"\U000024C2-\U0001F251"
                    "]+", flags = re.UNICODE)
    
    return emoji_pattern.sub(r'', text) 


def RemoveHttp(text):
    http = "https?://\S+|www\.\S+"
    pattern = r"({})".format(http)
    return re.sub(pattern, "", text)


regexp = RegexpTokenizer("[\w']+")
def RemoveStopwords(text, stopwords):
    return " ".join(word for word in regexp.tokenize(text) if word.lower() not in stopwords)

# %% [markdown]
# #### Tradutor de texto - Azure AI Translator

# %%
# Chave e endpoint
key = azure_ai_translator_key
endpoint = "https://api.cognitive.microsofttranslator.com"
location = "eastus"

path = '/translate'
constructed_url = endpoint + path

params = {
    'api-version': '3.0',
    'from': 'pt',
    'to': ['en']
}

headers = {
    'Ocp-Apim-Subscription-Key': key,
    'Ocp-Apim-Subscription-Region': location,
    'Content-type': 'application/json',
    'X-ClientTraceId': str(uuid.uuid4())
}


def TranslateText(text):
    body = [{
        'text': text
    }]

    request = requests.post(constructed_url, params=params, headers=headers, json=body)
    response = request.json()

    return RemovePunctuation(json.dumps(response[0]["translations"][0]["text"], sort_keys=True, ensure_ascii=False, indent=4, separators=(',', ': ')))

print(TranslateText('Testando'))
# Out:
# Testing

# %% [markdown]
# #### Análise de sentimento - Azure AI Text Analysis

# %%
# Essa função funciona melhor com o texto em português, mas nada impede de fazer em inglês e ver os resultados
def SentimentAnalysis(text):
    endpoint = "https://sentiment-analysis-ds.cognitiveservices.azure.com/"
    key = azure_ai_sentiment_key

    text_analytics_client = TextAnalyticsClient(endpoint=endpoint, credential=AzureKeyCredential(key))

    result = text_analytics_client.analyze_sentiment([text], show_opinion_mining=True)
    
    sentiment = result[0]['sentiment']
   
    return sentiment 

print(SentimentAnalysis("Teste"))
# Out:
# neutral

# %% [markdown]
# #### Análise de emoção - IBM Watson

# %%
# config da chave API
authenticator = IAMAuthenticator(ibm_watson_emotion_key)

# Cria uma instância do serviço NLU e define a URL
natural_language_understanding = NaturalLanguageUnderstandingV1(
    version='2021-08-01',
    authenticator=authenticator
)
natural_language_understanding.set_service_url('https://api.us-east.natural-language-understanding.watson.cloud.ibm.com/instances/186a3145-a256-4653-945a-cb77e4542307')

# %%
# Função
def EmotionAnalysis(text):
    try:
        # Solicitação de análise de emoção
        response = natural_language_understanding.analyze(
            text=text,
            features=Features(emotion=EmotionOptions())
        ).get_result()

        # Extrair emoções
        emocoes = response['emotion']['document']['emotion']
        return max(emocoes, key=emocoes.get)
    except:
        return "insuficiente"

print(EmotionAnalysis("I'm happy today"))
# Out:
# joy

# %% [markdown]
# #### Leitura e tratamento dos dados
# Há outros datasets com textos disponiveis em 'data'

# %%
ds = pd.read_csv('data/ptbr-order_reviews.csv')
df = pd.DataFrame(ds.sample(200))
df = df[["score","title","opinion"]].dropna()
# df = df[["order_id","score","title","opinion"]].dropna()
display(df)
# Out:
#        score                      title  \
# 53289      5      Excelente fornecedor!
# 68254      5            Sempre perfeita
# 50553      1          Atraso na entrega
# 84578      4                        Bom
# 89538      2                    Regular
# 46800      5          super recomendado
# 31170      5                Bom demais!
# 57893      5  Compra do produto Rebotec
# 16727      5                    Tudo ok
# 44782      1        cancelamento compra
# 39142      4                Bom produto
# 8670       5               Agradecemos
# 55734      5                  Recomendo
# 30837      5            SUPER RECOMENDO
# 67945      4            super recomendo
# 22451      3                        Bom
# 48599      4         moringa oliorifera
# 21035      5             Comprou chegou
# 32568      5                    Amei!!
# 47047      1    Não recebi a mercadoria
# 83995      1  Anúncio ambíguo dá errado
# 40867      1  Não recebi todos os produ
# 75050      4                  recomendo
# 39576      4                  recomendo
# 20275      1      Produto não entregue.
# 45996      5                 Entrega ok
# 26398      5                          5
# 15086      5                     Otimo!
# 56056      1             ainda n recebi
# 75643      1         Nunca mais compro!
#
#                                                  opinion
# 53289                           Entregue antes do prazo!
# 68254  O produto é de excelente qualidade. Entrega an...
# 50553  Comprei achando que iria receber em três dias ...
# 84578                           Produto bom, pelo preço.
# 89538  Comprei 2 produtos chegou apenas 1. Aguardo re...
# 46800                                          muito bom
# 31170  A entrega do produto veio antes do esperado. A...
# 57893  Estou satisfeito com a entrega do produto. Par...
# 16727                                Otimo. Top de linha
# 44782  Foi cancelado a compra antes da emissão de not...
# 39142  Produto de boa qualidade, mas a pelicula nao p...
# 8670                    Tudo maravilhoso muito obrigada
# 55734                            Entrega antes do prazo!
# 30837  Produto chegou mais rápido do que eu esperava,...
# 67945       Recebi corretamente e até antes do esperado
# 22451                                                Bom
# 48599  Recomendo a loja,entregaram no prazo e o produ...
# 21035                Pra mim,é o melhor Site de compras.
# 32568  Ainda não instalei, mas eu me surpreendi com o...
# 47047  Não recebi minha encomenda é já mostrou pelo r...
# 83995  Lentes de contato são positivas, para hipermet...
# 40867  Falta duas unidades do outro produto que compr...
# 75050  Pois bem, como acima citado o produto foi entr...
# 39576  Comprei dois produtos, o primeiro chegou certi...
# 20275  Infelizmente, a empresa trabalha com os Correi...
# 45996                      Entregue bem antes da data!!
# 26398                                     Rápida entrega
# 15086                                        Tudo certo!
# 56056  o produto ainda n chegou a minha residencia e ...
# 75643  Comprei 2 bolsas com 2 garrafas do fluminensev...

# %% [markdown]
# #### Tratamento e tradução do texto
# Remoção de pontuações, emoji, link http, brancos, entre outros..

# %%
stopwords_pt = set(stopwords.words('english'))

def TextNormalizer(text):
    text = unidecode.unidecode(text)
    text = re.sub('\n', '', text)
    text = RemoveHttp(text)
    text = RemoveEmoji(text)
    text = RemovePunctuation(text)
    text = RemoveStopwords(text, stopwords_pt)
    text = RemoveBlank(text)   
    text = TextToLower(text)
    text = TranslateText(text)
    
    return text

# %%
# Normalização e tradução do texto
# Faça teste tanto do Azure Ai quanto do Ibm Watson com texto em inglês e português, ele varia o retorno a depender do idioma
df['opinion_en'] = df['opinion'].apply(TextNormalizer)
df['title_en'] = df['title'].apply(TextNormalizer)

# %% [markdown]
# #### Aplicação das funções de sentimento e emoção nos textos
# Concatenado titulo com texto para melhoria do entendimento do sentimento e emoção

# %%
# Aplicado sob a coluna em pt-BR
df['sentiment'] = df['opinion'].apply(SentimentAnalysis)
display(df.head(5))
# Out:
#        score                  title  \
# 53289      5  Excelente fornecedor!
# 68254      5        Sempre perfeita
# 50553      1      Atraso na entrega
# 84578      4                    Bom
# 89538      2                Regular
#
#                                                  opinion  \
# 53289                           Entregue antes do prazo!
# 68254  O produto é de excelente qualidade. Entrega an...
# 50553  Comprei achando que iria receber em três dias ...
# 84578                           Produto bom, pelo preço.
# 89538  Comprei 2 produtos chegou apenas 1. Aguardo re...
#
#                                               opinion_en            title_en  \
# 53289                        delivered ahead of schedule  Excellent supplier
# 68254  product is of excellent quality delivery befor...      always perfect
# 50553  I bought thinking I would receive it in three ...   Delay in delivery
# 84578                         Good product for the price                good
# 89538  I bought 2 products arrived only 1 I wait for ...             regular
#
#       sentiment
# 53289   neutral
# 68254  positive
# 50553  negative
# 84578  positive
# 89538  negative

# %%
df['emotion_text'] = df['title_en'] + " " + df['opinion_en']
df['emotion'] = df['emotion_text'].apply(EmotionAnalysis)
df = df.drop('emotion_text', axis='columns')

# %%
display(df)
# Out:
#        score                      title  \
# 53289      5      Excelente fornecedor!
# 68254      5            Sempre perfeita
# 50553      1          Atraso na entrega
# 84578      4                        Bom
# 89538      2                    Regular
# 46800      5          super recomendado
# 31170      5                Bom demais!
# 57893      5  Compra do produto Rebotec
# 16727      5                    Tudo ok
# 44782      1        cancelamento compra
# 39142      4                Bom produto
# 8670       5               Agradecemos
# 55734      5                  Recomendo
# 30837      5            SUPER RECOMENDO
# 67945      4            super recomendo
# 22451      3                        Bom
# 48599      4         moringa oliorifera
# 21035      5             Comprou chegou
# 32568      5                    Amei!!
# 47047      1    Não recebi a mercadoria
# 83995      1  Anúncio ambíguo dá errado
# 40867      1  Não recebi todos os produ
# 75050      4                  recomendo
# 39576      4                  recomendo
# 20275      1      Produto não entregue.
# 45996      5                 Entrega ok
# 26398      5                          5
# 15086      5                     Otimo!
# 56056      1             ainda n recebi
# 75643      1         Nunca mais compro!
#
#                                                  opinion  \
# 53289                           Entregue antes do prazo!
# 68254  O produto é de excelente qualidade. Entrega an...
# 50553  Comprei achando que iria receber em três dias ...
# 84578                           Produto bom, pelo preço.
# 89538  Comprei 2 produtos chegou apenas 1. Aguardo re...
# 46800                                          muito bom
# 31170  A entrega do produto veio antes do esperado. A...
# 57893  Estou satisfeito com a entrega do produto. Par...
# 16727                                Otimo. Top de linha
# 44782  Foi cancelado a compra antes da emissão de not...
# 39142  Produto de boa qualidade, mas a pelicula nao p...
# 8670                    Tudo maravilhoso muito obrigada
# 55734                            Entrega antes do prazo!
# 30837  Produto chegou mais rápido do que eu esperava,...
# 67945       Recebi corretamente e até antes do esperado
# 22451                                                Bom
# 48599  Recomendo a loja,entregaram no prazo e o produ...
# 21035                Pra mim,é o melhor Site de compras.
# 32568  Ainda não instalei, mas eu me surpreendi com o...
# 47047  Não recebi minha encomenda é já mostrou pelo r...
# 83995  Lentes de contato são positivas, para hipermet...
# 40867  Falta duas unidades do outro produto que compr...
# 75050  Pois bem, como acima citado o produto foi entr...
# 39576  Comprei dois produtos, o primeiro chegou certi...
# 20275  Infelizmente, a empresa trabalha com os Correi...
# 45996                      Entregue bem antes da data!!
# 26398                                     Rápida entrega
# 15086                                        Tudo certo!
# 56056  o produto ainda n chegou a minha residencia e ...
# 75643  Comprei 2 bolsas com 2 garrafas do fluminensev...
#
#                                               opinion_en  \
# 53289                        delivered ahead of schedule
# 68254  product is of excellent quality delivery befor...
# 50553  I bought thinking I would receive it in three ...
# 84578                         Good product for the price
# 89538  I bought 2 products arrived only 1 I wait for ...
# 46800                                          Very good
# 31170  delivery product came before expected quality ...
# 57893  I am satisfied with delivery product congratul...
# 16727                              Great top of the line
# 44782  Purchase was canceled before the invoice was i...
# 39142  good quality product but film does not take th...
# 8670            everything wonderful thank you very much
# 55734                           Delivery before deadline
# 30837  Product arrived faster than I expected in grea...
# 67945  I received it correctly and even earlier expected
# 22451                                               good
# 48599  I recommend storedelivered deadline and produc...
# 21035                          For me best shopping site
# 32568  I haven't installed it yet but I surprised wit...
# 47047  I didn't receive my order and it already showe...
# 83995  contact lenses are positive for hyperopia or n...
# 40867         Two units missing another product I bought
# 75050  as well as mentioned above product was deliver...
# 39576  I bought two products first it arrived right a...
# 20275  Unfortunately the company works with the Post ...
# 45996                       delivered well ahead of date
# 26398                                      Fast delivery
# 15086                                          All right
# 56056  product has not yet arrived at my residence an...
# 75643  I bought 2 bags with 2 bottles fluminensevin t...
#
#                                 title_en sentiment       emotion
# 53289                 Excellent supplier   neutral           joy
# 68254                     always perfect  positive           joy
# 50553                  Delay in delivery  negative       sadness
# 84578                               good  positive           joy
# 89538                            regular  negative           joy
# 46800                  Super recommended  positive           joy
# 31170                           Too good  positive           joy
# 57893                Buy Rebotec product  positive           joy
# 16727                      everything ok  positive           joy
# 44782              Cancellation purchase  negative       sadness
# 39142                       Good product     mixed           joy
# 8670                               Thank  positive           joy
# 55734                          Recommend   neutral          fear
# 30837                 I highly recommend  positive           joy
# 67945                 I highly recommend  positive           joy
# 22451                               good   neutral  insuficiente
# 48599                 Moringa oliorifera  positive           joy
# 21035                     Bought arrived  positive       sadness
# 32568                              Loved     mixed       sadness
# 47047             I didn't receive goods  negative       sadness
# 83995            Ambiguous ad goes wrong  negative       sadness
# 40867  I didn't receive all the products  negative       sadness
# 75050                          Recommend  negative       sadness
# 39576                          Recommend  negative       sadness
# 20275              Product not delivered  negative       sadness
# 45996                        Delivery ok  positive         anger
# 26398                                  5  positive  insuficiente
# 15086                              Great  positive           joy
# 56056          I haven't received it yet  negative       sadness
# 75643               I'll never buy again  negative       sadness
